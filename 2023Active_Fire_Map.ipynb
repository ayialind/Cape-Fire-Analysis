# %%
# !pip install geodatasets cartopy

import geopandas
import matplotlib.pyplot as plt
from cartopy import crs as ccrs
from geodatasets import get_path

# %%
Cape = geopandas.read_file('Biodiversity_Hotspots_2016_(feature_layer).geojson')

# and test our libraries loaded

Cape.plot()
# Out:
# <Axes: >

# %%
import pandas as pd
gdf = geopandas.GeoDataFrame(
    df, geometry=geopandas.points_from_xy(df.longitude, df.latitude))
df = pd.read_csv('2023_active_fires.csv')
ax = Cape.plot(color="lightgrey", edgecolor="black")

# We can now plot our ``GeoDataFrame``.
gdf.plot(ax=ax, color="red", markersize=0.1)

plt.show()
