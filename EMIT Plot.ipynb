# %%
# Import required libraries
import os
import folium
import earthaccess
import warnings
import folium.plugins
import pandas as pd
import geopandas as gpd
import math

from branca.element import Figure
from IPython.display import display
from shapely import geometry
from skimage import io
from datetime import timedelta
from shapely.geometry.polygon import orient
from matplotlib import pyplot as plt

# %%
polygon = gpd.read_file('../../Cape Fire Analysis/Cape Floristic Region Data/Cape_Floristic_Region.geojson')
polygon.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
polygon
# Out:
#    OBJECTID                   NAME          TYPE  \
# 0         4  Cape Floristic Region  hotspot_area
#
#                             NAME_TYPE  Color   Shape__Area  Shape__Length  \
# 0  Cape Floristic Region_hotspot_area      1  1.129779e+11   1.110659e+07
#
#                                             geometry
# 0  MULTIPOLYGON (((17.67123 -29.86328, 17.66259 -...

# %%
# Merge all Polygon geometries and create external boundary
roi_poly = polygon.unary_union.envelope
# Re-order vertices to counterclockwise
roi_poly = orient(roi_poly, sign=1.0)

# %%
df = pd.DataFrame({"Name":["ROI Bounding Box"]})
cfr_bbox = gpd.GeoDataFrame({"Name":["ROI Bounding Box"], "geometry":[roi_poly]},crs="EPSG:4326")
cfr_bbox
# Out:
#                Name                                           geometry
# 0  ROI Bounding Box  POLYGON ((17.42036 -34.83983, 25.70225 -34.839...

# %%
def convert_bounds(bbox, invert_y=False):
    """
    Helper method for changing bounding box representation to leaflet notation

    ``(lon1, lat1, lon2, lat2) -> ((lat1, lon1), (lat2, lon2))``
    """
    x1, y1, x2, y2 = bbox
    if invert_y:
        y1, y2 = y2, y1
    return ((y1, x1), (y2, x2))

# %%
fig = Figure(width="750px", height="375px")
map1 = folium.Map(tiles='https://mt1.google.com/vt/lyrs=y&x={x}&y={y}&z={z}', attr='Google')
fig.add_child(map1)

# Add Convex Hull Polygon
folium.GeoJson(cfr_bbox,
                name='bounding_box',
                ).add_to(map1)

map1.add_child(folium.LayerControl())
map1.fit_bounds(bounds=convert_bounds(polygon.unary_union.bounds))
display(fig)
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_548ceb210d401bd20c8975d41196d5e3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_548ceb210d401bd20c8975d41196d5e3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_548ceb210d401bd20c8975d41196d5e3 = L.map(
#                 &quot;map_548ceb210d401bd20c8975d41196d5e3&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_93ad6abfaf25488e32ea68e30849f1f7 = L.tileLayer(
#                 &quot;https://mt1.google.com/vt/lyrs=y\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {&quot;attribution&quot;: &quot;Google&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_93ad6abfaf25488e32ea68e30849f1f7.addTo(map_548ceb210d401bd20c8975d41196d5e3);
#
#
#
#         function geo_json_77e317e0671611d52f71e36a37c2c3a5_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_77e317e0671611d52f71e36a37c2c3a5 = L.geoJson(null, {
#                 onEachFeature: geo_json_77e317e0671611d52f71e36a37c2c3a5_onEachFeature,
#
#         });
#
#         function geo_json_77e317e0671611d52f71e36a37c2c3a5_add (data) {
#             geo_json_77e317e0671611d52f71e36a37c2c3a5
#                 .addData(data);
#         }
#             geo_json_77e317e0671611d52f71e36a37c2c3a5_add({&quot;bbox&quot;: [17.4203635516196, -34.8398286881487, 25.7022465662669, -29.3215214110369], &quot;features&quot;: [{&quot;bbox&quot;: [17.4203635516196, -34.8398286881487, 25.7022465662669, -29.3215214110369], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[17.4203635516196, -34.8398286881487], [25.7022465662669, -34.8398286881487], [25.7022465662669, -29.3215214110369], [17.4203635516196, -29.3215214110369], [17.4203635516196, -34.8398286881487]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;Name&quot;: &quot;ROI Bounding Box&quot;}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_77e317e0671611d52f71e36a37c2c3a5.addTo(map_548ceb210d401bd20c8975d41196d5e3);
#
#
#             var layer_control_8fec1f75653bd39e9aa5a031eec46f33_layers = {
#                 base_layers : {
#                     &quot;https://mt1.google.com/vt/lyrs=y\u0026x={x}\u0026y={y}\u0026z={z}&quot; : tile_layer_93ad6abfaf25488e32ea68e30849f1f7,
#                 },
#                 overlays :  {
#                     &quot;bounding_box&quot; : geo_json_77e317e0671611d52f71e36a37c2c3a5,
#                 },
#             };
#             let layer_control_8fec1f75653bd39e9aa5a031eec46f33 = L.control.layers(
#                 layer_control_8fec1f75653bd39e9aa5a031eec46f33_layers.base_layers,
#                 layer_control_8fec1f75653bd39e9aa5a031eec46f33_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_548ceb210d401bd20c8975d41196d5e3);
#
#
#
#             map_548ceb210d401bd20c8975d41196d5e3.fitBounds(
#                 [[-34.8398286881487, 17.4203635516196], [-29.3215214110369, 25.7022465662669]],
#                 {}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" width="750px" height="375px"style="border:none !important;" "allowfullscreen" "webkitallowfullscreen" "mozallowfullscreen"></iframe>

# %%
roi = list(roi_poly.exterior.coords)

# %%
emit_collection_query = earthaccess.collection_query().keyword('EMIT L2A Reflectance')
emit_collection_query.fields(['ShortName','EntryTitle','Version']).get()
# Out:
# [{
#    "meta": {
#      "concept-id": "C2408750690-LPCLOUD",
#      "granule-count": 61723,
#      "provider-id": "LPCLOUD"
#    },
#    "umm": {
#      "ShortName": "EMITL2ARFL",
#      "EntryTitle": "EMIT L2A Estimated Surface Reflectance and Uncertainty and Masks 60 m V001",
#      "Version": "001"
#    }
#  }]

# %%
date_range = ('2023-02-01','2023-2-28')

# %%
concept_ids = ['C2408750690-LPCLOUD']

# %%
results = earthaccess.search_data(
    concept_id=concept_ids,
    polygon=roi,
    temporal=('2023-1-01','2023-1-31'),
    count = 584,
    cloud_cover = (0,10) 
)
# Out:
# Granules found: 39

# %%
def get_shapely_object(result:earthaccess.results.DataGranule):
    # Get Geometry Keys
    geo = result['umm']['SpatialExtent']['HorizontalSpatialDomain']['Geometry']
    keys = geo.keys()

    if 'BoundingRectangles' in keys:
        bounding_rectangle = geo['BoundingRectangles'][0]
        # Create bbox tuple
        bbox_coords = (bounding_rectangle['WestBoundingCoordinate'],bounding_rectangle['SouthBoundingCoordinate'],
                    bounding_rectangle['EastBoundingCoordinate'],bounding_rectangle['NorthBoundingCoordinate'])
        # Create shapely geometry from bbox
        shape = geometry.box(*bbox_coords, ccw=True)
    elif 'GPolygons' in keys:
        points = geo['GPolygons'][0]['Boundary']['Points']
        # Create shapely geometry from polygons
        shape = geometry.Polygon([[p['Longitude'],p['Latitude']] for p in points])
    else:
         raise ValueError('Provided result does not contain bounding boxes/polygons or is incompatible.')
    return(shape)

# Retrieve png browse image if it exists or first jpg in list of urls
def get_png(result:earthaccess.results.DataGranule):
    https_links = [link for link in result.dataviz_links() if 'https' in link]
    if len(https_links) == 1:
        browse = https_links[0]
    elif len(https_links) == 0:
        browse = 'no browse image'
        warnings.warn(f"There is no browse imagery for {result['umm']['GranuleUR']}.")
    else:
        browse = [png for png in https_links if '.png' in png][0]
    return(browse)

# %%
# Create Dataframe of Results Metadata
results_df = pd.json_normalize(results)
# Create shapely polygons for result
geometries = [get_shapely_object(results[index]) for index in results_df.index.to_list()]
# Convert to GeoDataframe
gdf = gpd.GeoDataFrame(results_df, geometry=geometries, crs="EPSG:4326")
# Remove results df, no longer needed
del results_df
# Add browse imagery links
gdf['browse'] = [get_png(granule) for granule in results]
gdf['shortname'] = [result['umm']['CollectionReference']['ShortName'] for result in results]
# Preview GeoDataframe
print(f'{gdf.shape[0]} granules total')
# Out:
# 39 granules total

# %%
gdf
# Out:
#            size meta.concept-type      meta.concept-id  meta.revision-id  \
# 0   3579.872540           granule  G2621941049-LPCLOUD                 1
# 1   3579.853838           granule  G2621941455-LPCLOUD                 1
# 2   3579.503963           granule  G2621941650-LPCLOUD                 1
# 3   3579.813070           granule  G2621944360-LPCLOUD                 1
# 4   3579.977796           granule  G2621944396-LPCLOUD                 1
# 5   3580.095710           granule  G2621944423-LPCLOUD                 1
# 6   3579.942201           granule  G2621944230-LPCLOUD                 1
# 7   3579.834721           granule  G2621944458-LPCLOUD                 1
# 8   3580.331309           granule  G2621944426-LPCLOUD                 1
# 9   3578.975523           granule  G2622198490-LPCLOUD                 1
# 10  3579.568277           granule  G2622322687-LPCLOUD                 1
# 11  3579.687906           granule  G2622357633-LPCLOUD                 1
# 12  3580.295828           granule  G2622358232-LPCLOUD                 1
# 13  3579.750184           granule  G2622358384-LPCLOUD                 1
# 14  3579.654291           granule  G2622397031-LPCLOUD                 1
# 15  3579.731799           granule  G2622397319-LPCLOUD                 1
# 16  3579.923376           granule  G2622494437-LPCLOUD                 1
# 17  3580.090855           granule  G2622494846-LPCLOUD                 1
# 18  3579.884403           granule  G2622495110-LPCLOUD                 1
# 19  3578.852185           granule  G2622650588-LPCLOUD                 1
# 20  3580.418997           granule  G2622651787-LPCLOUD                 1
# 21  3579.366050           granule  G2622652122-LPCLOUD                 1
# 22  3580.145051           granule  G2622751284-LPCLOUD                 1
# 23  3579.972368           granule  G2622751999-LPCLOUD                 1
# 24  5190.058483           granule  G2622757643-LPCLOUD                 1
# 25  3580.046962           granule  G2623151805-LPCLOUD                 1
# 26  3579.238238           granule  G2623152406-LPCLOUD                 1
# 27  3579.716686           granule  G2623154768-LPCLOUD                 1
# 28  3579.633206           granule  G2623154707-LPCLOUD                 1
# 29  3579.995796           granule  G2623278892-LPCLOUD                 1
# 30  3580.369751           granule  G2623280918-LPCLOUD                 1
# 31  3580.025961           granule  G2623281376-LPCLOUD                 1
# 32  3579.885658           granule  G2623281651-LPCLOUD                 1
# 33  3579.843275           granule  G2623284593-LPCLOUD                 1
# 34  5190.792187           granule  G2623289323-LPCLOUD                 1
# 35  3579.150054           granule  G2623663660-LPCLOUD                 1
# 36  3579.132874           granule  G2623663868-LPCLOUD                 1
# 37  3579.305646           granule  G2623665605-LPCLOUD                 1
# 38  3579.454743           granule  G2623667084-LPCLOUD                 1
#
#                                   meta.native-id meta.provider-id  \
# 0   EMIT_L2A_RFL_001_20230107T082503_2300705_010          LPCLOUD
# 1   EMIT_L2A_RFL_001_20230107T082515_2300705_011          LPCLOUD
# 2   EMIT_L2A_RFL_001_20230107T082527_2300705_012          LPCLOUD
# 3   EMIT_L2A_RFL_001_20230107T082539_2300705_013          LPCLOUD
# 4   EMIT_L2A_RFL_001_20230107T082550_2300705_014          LPCLOUD
# 5   EMIT_L2A_RFL_001_20230107T082602_2300705_015          LPCLOUD
# 6   EMIT_L2A_RFL_001_20230107T082614_2300705_016          LPCLOUD
# 7   EMIT_L2A_RFL_001_20230107T082626_2300705_017          LPCLOUD
# 8   EMIT_L2A_RFL_001_20230107T082638_2300705_018          LPCLOUD
# 9   EMIT_L2A_RFL_001_20230111T064936_2301104_018          LPCLOUD
# 10  EMIT_L2A_RFL_001_20230114T140929_2301409_012          LPCLOUD
# 11  EMIT_L2A_RFL_001_20230115T132020_2301508_013          LPCLOUD
# 12  EMIT_L2A_RFL_001_20230115T132032_2301508_014          LPCLOUD
# 13  EMIT_L2A_RFL_001_20230115T132044_2301508_015          LPCLOUD
# 14  EMIT_L2A_RFL_001_20230116T123238_2301608_011          LPCLOUD
# 15  EMIT_L2A_RFL_001_20230116T123249_2301608_012          LPCLOUD
# 16  EMIT_L2A_RFL_001_20230119T114247_2301907_005          LPCLOUD
# 17  EMIT_L2A_RFL_001_20230119T114259_2301907_006          LPCLOUD
# 18  EMIT_L2A_RFL_001_20230119T114311_2301907_007          LPCLOUD
# 19  EMIT_L2A_RFL_001_20230122T105455_2302207_004          LPCLOUD
# 20  EMIT_L2A_RFL_001_20230122T105507_2302207_005          LPCLOUD
# 21  EMIT_L2A_RFL_001_20230122T105519_2302207_006          LPCLOUD
# 22  EMIT_L2A_RFL_001_20230123T100627_2302306_007          LPCLOUD
# 23  EMIT_L2A_RFL_001_20230123T100639_2302306_008          LPCLOUD
# 24  EMIT_L2A_RFL_001_20230123T100726_2302306_012          LPCLOUD
# 25  EMIT_L2A_RFL_001_20230126T091804_2302606_017          LPCLOUD
# 26  EMIT_L2A_RFL_001_20230126T091816_2302606_018          LPCLOUD
# 27  EMIT_L2A_RFL_001_20230126T091828_2302606_019          LPCLOUD
# 28  EMIT_L2A_RFL_001_20230126T091840_2302606_020          LPCLOUD
# 29  EMIT_L2A_RFL_001_20230127T082907_2302705_013          LPCLOUD
# 30  EMIT_L2A_RFL_001_20230127T082919_2302705_014          LPCLOUD
# 31  EMIT_L2A_RFL_001_20230127T082931_2302705_015          LPCLOUD
# 32  EMIT_L2A_RFL_001_20230127T082943_2302705_016          LPCLOUD
# 33  EMIT_L2A_RFL_001_20230127T082955_2302705_017          LPCLOUD
# 34  EMIT_L2A_RFL_001_20230127T083007_2302705_018          LPCLOUD
# 35  EMIT_L2A_RFL_001_20230130T074026_2303005_026          LPCLOUD
# 36  EMIT_L2A_RFL_001_20230130T074038_2303005_027          LPCLOUD
# 37  EMIT_L2A_RFL_001_20230130T074049_2303005_028          LPCLOUD
# 38  EMIT_L2A_RFL_001_20230130T074101_2303005_029          LPCLOUD
#
#                           meta.format        meta.revision-date  \
# 0   application/vnd.nasa.cmr.umm+json  2023-02-27T19:32:40.885Z
# 1   application/vnd.nasa.cmr.umm+json  2023-02-27T19:33:47.290Z
# 2   application/vnd.nasa.cmr.umm+json  2023-02-27T19:34:09.858Z
# 3   application/vnd.nasa.cmr.umm+json  2023-02-27T19:38:00.215Z
# 4   application/vnd.nasa.cmr.umm+json  2023-02-27T19:38:06.107Z
# 5   application/vnd.nasa.cmr.umm+json  2023-02-27T19:38:15.369Z
# 6   application/vnd.nasa.cmr.umm+json  2023-02-27T19:37:42.845Z
# 7   application/vnd.nasa.cmr.umm+json  2023-02-27T19:38:34.922Z
# 8   application/vnd.nasa.cmr.umm+json  2023-02-27T19:38:17.281Z
# 9   application/vnd.nasa.cmr.umm+json  2023-02-28T02:36:04.121Z
# 10  application/vnd.nasa.cmr.umm+json  2023-02-28T05:36:28.327Z
# 11  application/vnd.nasa.cmr.umm+json  2023-02-28T06:35:33.406Z
# 12  application/vnd.nasa.cmr.umm+json  2023-02-28T06:36:43.010Z
# 13  application/vnd.nasa.cmr.umm+json  2023-02-28T06:37:01.074Z
# 14  application/vnd.nasa.cmr.umm+json  2023-02-28T07:34:01.926Z
# 15  application/vnd.nasa.cmr.umm+json  2023-02-28T07:34:51.510Z
# 16  application/vnd.nasa.cmr.umm+json  2023-02-28T10:23:32.365Z
# 17  application/vnd.nasa.cmr.umm+json  2023-02-28T10:24:37.979Z
# 18  application/vnd.nasa.cmr.umm+json  2023-02-28T10:25:32.791Z
# 19  application/vnd.nasa.cmr.umm+json  2023-02-28T14:47:10.648Z
# 20  application/vnd.nasa.cmr.umm+json  2023-02-28T14:48:43.317Z
# 21  application/vnd.nasa.cmr.umm+json  2023-02-28T14:49:33.475Z
# 22  application/vnd.nasa.cmr.umm+json  2023-02-28T16:38:06.550Z
# 23  application/vnd.nasa.cmr.umm+json  2023-02-28T16:39:39.087Z
# 24  application/vnd.nasa.cmr.umm+json  2023-02-28T16:50:15.323Z
# 25  application/vnd.nasa.cmr.umm+json  2023-03-01T01:16:29.182Z
# 26  application/vnd.nasa.cmr.umm+json  2023-03-01T01:16:53.385Z
# 27  application/vnd.nasa.cmr.umm+json  2023-03-01T01:18:40.839Z
# 28  application/vnd.nasa.cmr.umm+json  2023-03-01T01:18:36.457Z
# 29  application/vnd.nasa.cmr.umm+json  2023-03-01T03:32:34.378Z
# 30  application/vnd.nasa.cmr.umm+json  2023-03-01T03:34:39.840Z
# 31  application/vnd.nasa.cmr.umm+json  2023-03-01T03:35:58.109Z
# 32  application/vnd.nasa.cmr.umm+json  2023-03-01T03:36:36.354Z
# 33  application/vnd.nasa.cmr.umm+json  2023-03-01T03:39:45.278Z
# 34  application/vnd.nasa.cmr.umm+json  2023-03-01T03:46:20.907Z
# 35  application/vnd.nasa.cmr.umm+json  2023-03-01T13:23:34.424Z
# 36  application/vnd.nasa.cmr.umm+json  2023-03-01T13:24:18.466Z
# 37  application/vnd.nasa.cmr.umm+json  2023-03-01T13:27:40.033Z
# 38  application/vnd.nasa.cmr.umm+json  2023-03-01T13:30:35.739Z
#
#    umm.TemporalExtent.RangeDateTime.BeginningDateTime  \
# 0                                2023-01-07T08:25:03Z
# 1                                2023-01-07T08:25:15Z
# 2                                2023-01-07T08:25:27Z
# 3                                2023-01-07T08:25:39Z
# 4                                2023-01-07T08:25:50Z
# 5                                2023-01-07T08:26:02Z
# 6                                2023-01-07T08:26:14Z
# 7                                2023-01-07T08:26:26Z
# 8                                2023-01-07T08:26:38Z
# 9                                2023-01-11T06:49:36Z
# 10                               2023-01-14T14:09:29Z
# 11                               2023-01-15T13:20:20Z
# 12                               2023-01-15T13:20:32Z
# 13                               2023-01-15T13:20:44Z
# 14                               2023-01-16T12:32:38Z
# 15                               2023-01-16T12:32:49Z
# 16                               2023-01-19T11:42:47Z
# 17                               2023-01-19T11:42:59Z
# 18                               2023-01-19T11:43:11Z
# 19                               2023-01-22T10:54:55Z
# 20                               2023-01-22T10:55:07Z
# 21                               2023-01-22T10:55:19Z
# 22                               2023-01-23T10:06:27Z
# 23                               2023-01-23T10:06:39Z
# 24                               2023-01-23T10:07:26Z
# 25                               2023-01-26T09:18:04Z
# 26                               2023-01-26T09:18:16Z
# 27                               2023-01-26T09:18:28Z
# 28                               2023-01-26T09:18:40Z
# 29                               2023-01-27T08:29:07Z
# 30                               2023-01-27T08:29:19Z
# 31                               2023-01-27T08:29:31Z
# 32                               2023-01-27T08:29:43Z
# 33                               2023-01-27T08:29:55Z
# 34                               2023-01-27T08:30:07Z
# 35                               2023-01-30T07:40:26Z
# 36                               2023-01-30T07:40:38Z
# 37                               2023-01-30T07:40:49Z
# 38                               2023-01-30T07:41:01Z
#
#    umm.TemporalExtent.RangeDateTime.EndingDateTime  ...  \
# 0                             2023-01-07T08:25:15Z  ...
# 1                             2023-01-07T08:25:27Z  ...
# 2                             2023-01-07T08:25:39Z  ...
# 3                             2023-01-07T08:25:50Z  ...
# 4                             2023-01-07T08:26:02Z  ...
# 5                             2023-01-07T08:26:14Z  ...
# 6                             2023-01-07T08:26:26Z  ...
# 7                             2023-01-07T08:26:38Z  ...
# 8                             2023-01-07T08:26:50Z  ...
# 9                             2023-01-11T06:49:48Z  ...
# 10                            2023-01-14T14:09:41Z  ...
# 11                            2023-01-15T13:20:32Z  ...
# 12                            2023-01-15T13:20:44Z  ...
# 13                            2023-01-15T13:20:55Z  ...
# 14                            2023-01-16T12:32:49Z  ...
# 15                            2023-01-16T12:33:01Z  ...
# 16                            2023-01-19T11:42:59Z  ...
# 17                            2023-01-19T11:43:11Z  ...
# 18                            2023-01-19T11:43:22Z  ...
# 19                            2023-01-22T10:55:07Z  ...
# 20                            2023-01-22T10:55:19Z  ...
# 21                            2023-01-22T10:55:31Z  ...
# 22                            2023-01-23T10:06:39Z  ...
# 23                            2023-01-23T10:06:51Z  ...
# 24                            2023-01-23T10:07:43Z  ...
# 25                            2023-01-26T09:18:16Z  ...
# 26                            2023-01-26T09:18:28Z  ...
# 27                            2023-01-26T09:18:40Z  ...
# 28                            2023-01-26T09:18:51Z  ...
# 29                            2023-01-27T08:29:19Z  ...
# 30                            2023-01-27T08:29:31Z  ...
# 31                            2023-01-27T08:29:43Z  ...
# 32                            2023-01-27T08:29:55Z  ...
# 33                            2023-01-27T08:30:07Z  ...
# 34                            2023-01-27T08:30:24Z  ...
# 35                            2023-01-30T07:40:38Z  ...
# 36                            2023-01-30T07:40:49Z  ...
# 37                            2023-01-30T07:41:01Z  ...
# 38                            2023-01-30T07:41:13Z  ...
#
#    umm.DataGranule.DayNightFlag  \
# 0                           Day
# 1                           Day
# 2                           Day
# 3                           Day
# 4                           Day
# 5                           Day
# 6                           Day
# 7                           Day
# 8                           Day
# 9                           Day
# 10                          Day
# 11                          Day
# 12                          Day
# 13                          Day
# 14                          Day
# 15                          Day
# 16                          Day
# 17                          Day
# 18                          Day
# 19                          Day
# 20                          Day
# 21                          Day
# 22                          Day
# 23                          Day
# 24                          Day
# 25                          Day
# 26                          Day
# 27                          Day
# 28                          Day
# 29                          Day
# 30                          Day
# 31                          Day
# 32                          Day
# 33                          Day
# 34                          Day
# 35                          Day
# 36                          Day
# 37                          Day
# 38                          Day
#
#     umm.DataGranule.ArchiveAndDistributionInformation  \
# 0   [{'Name': 'EMIT_L2A_RFL_001_20230107T082503_23...
# 1   [{'Name': 'EMIT_L2A_RFL_001_20230107T082515_23...
# 2   [{'Name': 'EMIT_L2A_RFL_001_20230107T082527_23...
# 3   [{'Name': 'EMIT_L2A_RFL_001_20230107T082539_23...
# 4   [{'Name': 'EMIT_L2A_RFL_001_20230107T082550_23...
# 5   [{'Name': 'EMIT_L2A_RFL_001_20230107T082602_23...
# 6   [{'Name': 'EMIT_L2A_RFL_001_20230107T082614_23...
# 7   [{'Name': 'EMIT_L2A_RFL_001_20230107T082626_23...
# 8   [{'Name': 'EMIT_L2A_RFL_001_20230107T082638_23...
# 9   [{'Name': 'EMIT_L2A_RFL_001_20230111T064936_23...
# 10  [{'Name': 'EMIT_L2A_RFL_001_20230114T140929_23...
# 11  [{'Name': 'EMIT_L2A_RFL_001_20230115T132020_23...
# 12  [{'Name': 'EMIT_L2A_RFL_001_20230115T132032_23...
# 13  [{'Name': 'EMIT_L2A_RFL_001_20230115T132044_23...
# 14  [{'Name': 'EMIT_L2A_RFL_001_20230116T123238_23...
# 15  [{'Name': 'EMIT_L2A_RFL_001_20230116T123249_23...
# 16  [{'Name': 'EMIT_L2A_RFL_001_20230119T114247_23...
# 17  [{'Name': 'EMIT_L2A_RFL_001_20230119T114259_23...
# 18  [{'Name': 'EMIT_L2A_RFL_001_20230119T114311_23...
# 19  [{'Name': 'EMIT_L2A_RFL_001_20230122T105455_23...
# 20  [{'Name': 'EMIT_L2A_RFL_001_20230122T105507_23...
# 21  [{'Name': 'EMIT_L2A_RFL_001_20230122T105519_23...
# 22  [{'Name': 'EMIT_L2A_RFL_001_20230123T100627_23...
# 23  [{'Name': 'EMIT_L2A_RFL_001_20230123T100639_23...
# 24  [{'Name': 'EMIT_L2A_RFL_001_20230123T100726_23...
# 25  [{'Name': 'EMIT_L2A_RFL_001_20230126T091804_23...
# 26  [{'Name': 'EMIT_L2A_RFL_001_20230126T091816_23...
# 27  [{'Name': 'EMIT_L2A_RFL_001_20230126T091828_23...
# 28  [{'Name': 'EMIT_L2A_RFL_001_20230126T091840_23...
# 29  [{'Name': 'EMIT_L2A_RFL_001_20230127T082907_23...
# 30  [{'Name': 'EMIT_L2A_RFL_001_20230127T082919_23...
# 31  [{'Name': 'EMIT_L2A_RFL_001_20230127T082931_23...
# 32  [{'Name': 'EMIT_L2A_RFL_001_20230127T082943_23...
# 33  [{'Name': 'EMIT_L2A_RFL_001_20230127T082955_23...
# 34  [{'Name': 'EMIT_L2A_RFL_001_20230127T083007_23...
# 35  [{'Name': 'EMIT_L2A_RFL_001_20230130T074026_23...
# 36  [{'Name': 'EMIT_L2A_RFL_001_20230130T074038_23...
# 37  [{'Name': 'EMIT_L2A_RFL_001_20230130T074049_23...
# 38  [{'Name': 'EMIT_L2A_RFL_001_20230130T074101_23...
#
#    umm.DataGranule.ProductionDateTime  \
# 0                2023-02-27T19:22:12Z
# 1                2023-02-27T19:22:47Z
# 2                2023-02-27T19:22:47Z
# 3                2023-02-27T19:24:16Z
# 4                2023-02-27T19:24:16Z
# 5                2023-02-27T19:24:16Z
# 6                2023-02-27T19:24:16Z
# 7                2023-02-27T19:24:16Z
# 8                2023-02-27T19:24:16Z
# 9                2023-02-28T02:24:00Z
# 10               2023-02-28T05:25:31Z
# 11               2023-02-28T06:24:55Z
# 12               2023-02-28T06:25:25Z
# 13               2023-02-28T06:25:54Z
# 14               2023-02-28T07:23:44Z
# 15               2023-02-28T07:25:09Z
# 16               2023-02-28T10:12:35Z
# 17               2023-02-28T10:13:42Z
# 18               2023-02-28T10:15:13Z
# 19               2023-02-28T14:31:46Z
# 20               2023-02-28T14:34:44Z
# 21               2023-02-28T14:34:45Z
# 22               2023-02-28T16:23:58Z
# 23               2023-02-28T16:24:29Z
# 24               2023-02-28T16:28:33Z
# 25               2023-03-01T01:03:50Z
# 26               2023-03-01T01:04:36Z
# 27               2023-03-01T01:07:32Z
# 28               2023-03-01T01:07:44Z
# 29               2023-03-01T03:21:56Z
# 30               2023-03-01T03:24:00Z
# 31               2023-03-01T03:24:45Z
# 32               2023-03-01T03:25:44Z
# 33               2023-03-01T03:29:14Z
# 34               2023-03-01T03:31:47Z
# 35               2023-03-01T13:11:30Z
# 36               2023-03-01T13:14:02Z
# 37               2023-03-01T13:16:30Z
# 38               2023-03-01T13:19:17Z
#
#                                         umm.Platforms  \
# 0   [{'ShortName': 'ISS', 'Instruments': [{'ShortN...
# 1   [{'ShortName': 'ISS', 'Instruments': [{'ShortN...
# 2   [{'ShortName': 'ISS', 'Instruments': [{'ShortN...
# 3   [{'ShortName': 'ISS', 'Instruments': [{'ShortN...
# 4   [{'ShortName': 'ISS', 'Instruments': [{'ShortN...
# 5   [{'ShortName': 'ISS', 'Instruments': [{'ShortN...
# 6   [{'ShortName': 'ISS', 'Instruments': [{'ShortN...
# 7   [{'ShortName': 'ISS', 'Instruments': [{'ShortN...
# 8   [{'ShortName': 'ISS', 'Instruments': [{'ShortN...
# 9   [{'ShortName': 'ISS', 'Instruments': [{'ShortN...
# 10  [{'ShortName': 'ISS', 'Instruments': [{'ShortN...
# 11  [{'ShortName': 'ISS', 'Instruments': [{'ShortN...
# 12  [{'ShortName': 'ISS', 'Instruments': [{'ShortN...
# 13  [{'ShortName': 'ISS', 'Instruments': [{'ShortN...
# 14  [{'ShortName': 'ISS', 'Instruments': [{'ShortN...
# 15  [{'ShortName': 'ISS', 'Instruments': [{'ShortN...
# 16  [{'ShortName': 'ISS', 'Instruments': [{'ShortN...
# 17  [{'ShortName': 'ISS', 'Instruments': [{'ShortN...
# 18  [{'ShortName': 'ISS', 'Instruments': [{'ShortN...
# 19  [{'ShortName': 'ISS', 'Instruments': [{'ShortN...
# 20  [{'ShortName': 'ISS', 'Instruments': [{'ShortN...
# 21  [{'ShortName': 'ISS', 'Instruments': [{'ShortN...
# 22  [{'ShortName': 'ISS', 'Instruments': [{'ShortN...
# 23  [{'ShortName': 'ISS', 'Instruments': [{'ShortN...
# 24  [{'ShortName': 'ISS', 'Instruments': [{'ShortN...
# 25  [{'ShortName': 'ISS', 'Instruments': [{'ShortN...
# 26  [{'ShortName': 'ISS', 'Instruments': [{'ShortN...
# 27  [{'ShortName': 'ISS', 'Instruments': [{'ShortN...
# 28  [{'ShortName': 'ISS', 'Instruments': [{'ShortN...
# 29  [{'ShortName': 'ISS', 'Instruments': [{'ShortN...
# 30  [{'ShortName': 'ISS', 'Instruments': [{'ShortN...
# 31  [{'ShortName': 'ISS', 'Instruments': [{'ShortN...
# 32  [{'ShortName': 'ISS', 'Instruments': [{'ShortN...
# 33  [{'ShortName': 'ISS', 'Instruments': [{'ShortN...
# 34  [{'ShortName': 'ISS', 'Instruments': [{'ShortN...
# 35  [{'ShortName': 'ISS', 'Instruments': [{'ShortN...
# 36  [{'ShortName': 'ISS', 'Instruments': [{'ShortN...
# 37  [{'ShortName': 'ISS', 'Instruments': [{'ShortN...
# 38  [{'ShortName': 'ISS', 'Instruments': [{'ShortN...
#
#                         umm.MetadataSpecification.URL  \
# 0   https://cdn.earthdata.nasa.gov/umm/granule/v1.6.5
# 1   https://cdn.earthdata.nasa.gov/umm/granule/v1.6.5
# 2   https://cdn.earthdata.nasa.gov/umm/granule/v1.6.5
# 3   https://cdn.earthdata.nasa.gov/umm/granule/v1.6.5
# 4   https://cdn.earthdata.nasa.gov/umm/granule/v1.6.5
# 5   https://cdn.earthdata.nasa.gov/umm/granule/v1.6.5
# 6   https://cdn.earthdata.nasa.gov/umm/granule/v1.6.5
# 7   https://cdn.earthdata.nasa.gov/umm/granule/v1.6.5
# 8   https://cdn.earthdata.nasa.gov/umm/granule/v1.6.5
# 9   https://cdn.earthdata.nasa.gov/umm/granule/v1.6.5
# 10  https://cdn.earthdata.nasa.gov/umm/granule/v1.6.5
# 11  https://cdn.earthdata.nasa.gov/umm/granule/v1.6.5
# 12  https://cdn.earthdata.nasa.gov/umm/granule/v1.6.5
# 13  https://cdn.earthdata.nasa.gov/umm/granule/v1.6.5
# 14  https://cdn.earthdata.nasa.gov/umm/granule/v1.6.5
# 15  https://cdn.earthdata.nasa.gov/umm/granule/v1.6.5
# 16  https://cdn.earthdata.nasa.gov/umm/granule/v1.6.5
# 17  https://cdn.earthdata.nasa.gov/umm/granule/v1.6.5
# 18  https://cdn.earthdata.nasa.gov/umm/granule/v1.6.5
# 19  https://cdn.earthdata.nasa.gov/umm/granule/v1.6.5
# 20  https://cdn.earthdata.nasa.gov/umm/granule/v1.6.5
# 21  https://cdn.earthdata.nasa.gov/umm/granule/v1.6.5
# 22  https://cdn.earthdata.nasa.gov/umm/granule/v1.6.5
# 23  https://cdn.earthdata.nasa.gov/umm/granule/v1.6.5
# 24  https://cdn.earthdata.nasa.gov/umm/granule/v1.6.5
# 25  https://cdn.earthdata.nasa.gov/umm/granule/v1.6.5
# 26  https://cdn.earthdata.nasa.gov/umm/granule/v1.6.5
# 27  https://cdn.earthdata.nasa.gov/umm/granule/v1.6.5
# 28  https://cdn.earthdata.nasa.gov/umm/granule/v1.6.5
# 29  https://cdn.earthdata.nasa.gov/umm/granule/v1.6.5
# 30  https://cdn.earthdata.nasa.gov/umm/granule/v1.6.5
# 31  https://cdn.earthdata.nasa.gov/umm/granule/v1.6.5
# 32  https://cdn.earthdata.nasa.gov/umm/granule/v1.6.5
# 33  https://cdn.earthdata.nasa.gov/umm/granule/v1.6.5
# 34  https://cdn.earthdata.nasa.gov/umm/granule/v1.6.5
# 35  https://cdn.earthdata.nasa.gov/umm/granule/v1.6.5
# 36  https://cdn.earthdata.nasa.gov/umm/granule/v1.6.5
# 37  https://cdn.earthdata.nasa.gov/umm/granule/v1.6.5
# 38  https://cdn.earthdata.nasa.gov/umm/granule/v1.6.5
#
#    umm.MetadataSpecification.Name umm.MetadataSpecification.Version  \
# 0                           UMM-G                             1.6.5
# 1                           UMM-G                             1.6.5
# 2                           UMM-G                             1.6.5
# 3                           UMM-G                             1.6.5
# 4                           UMM-G                             1.6.5
# 5                           UMM-G                             1.6.5
# 6                           UMM-G                             1.6.5
# 7                           UMM-G                             1.6.5
# 8                           UMM-G                             1.6.5
# 9                           UMM-G                             1.6.5
# 10                          UMM-G                             1.6.5
# 11                          UMM-G                             1.6.5
# 12                          UMM-G                             1.6.5
# 13                          UMM-G                             1.6.5
# 14                          UMM-G                             1.6.5
# 15                          UMM-G                             1.6.5
# 16                          UMM-G                             1.6.5
# 17                          UMM-G                             1.6.5
# 18                          UMM-G                             1.6.5
# 19                          UMM-G                             1.6.5
# 20                          UMM-G                             1.6.5
# 21                          UMM-G                             1.6.5
# 22                          UMM-G                             1.6.5
# 23                          UMM-G                             1.6.5
# 24                          UMM-G                             1.6.5
# 25                          UMM-G                             1.6.5
# 26                          UMM-G                             1.6.5
# 27                          UMM-G                             1.6.5
# 28                          UMM-G                             1.6.5
# 29                          UMM-G                             1.6.5
# 30                          UMM-G                             1.6.5
# 31                          UMM-G                             1.6.5
# 32                          UMM-G                             1.6.5
# 33                          UMM-G                             1.6.5
# 34                          UMM-G                             1.6.5
# 35                          UMM-G                             1.6.5
# 36                          UMM-G                             1.6.5
# 37                          UMM-G                             1.6.5
# 38                          UMM-G                             1.6.5
#
#                                              geometry  \
# 0   POLYGON ((18.23870 -28.49792, 17.69559 -29.066...
# 1   POLYGON ((18.80566 -29.03512, 18.26646 -29.609...
# 2   POLYGON ((19.37742 -29.56899, 18.84355 -30.149...
# 3   POLYGON ((19.95217 -30.09955, 19.42645 -30.685...
# 4   POLYGON ((20.54642 -30.62619, 20.01682 -31.218...
# 5   POLYGON ((21.13803 -31.15001, 20.61411 -31.747...
# 6   POLYGON ((21.74003 -31.67058, 21.21900 -32.274...
# 7   POLYGON ((22.34600 -32.18639, 21.82970 -32.796...
# 8   POLYGON ((22.96196 -32.69967, 22.44952 -33.316...
# 9   POLYGON ((23.21105 -32.20766, 22.69619 -32.817...
# 10  POLYGON ((17.27794 -28.41418, 16.62712 -29.039...
# 11  POLYGON ((18.72205 -32.62315, 17.97137 -33.243...
# 12  POLYGON ((19.33639 -32.10978, 18.59817 -32.730...
# 13  POLYGON ((19.93795 -31.59116, 19.21826 -32.213...
# 14  POLYGON ((24.60218 -32.85185, 23.85086 -33.470...
# 15  POLYGON ((25.22022 -32.33841, 24.47819 -32.959...
# 16  POLYGON ((19.23272 -33.01411, 18.47125 -33.633...
# 17  POLYGON ((19.85147 -32.50306, 19.10392 -33.124...
# 18  POLYGON ((20.46284 -31.98772, 19.72812 -32.610...
# 19  POLYGON ((17.36448 -30.00522, 16.67741 -30.630...
# 20  POLYGON ((17.94395 -29.47510, 17.26793 -30.100...
# 21  POLYGON ((18.51511 -28.94161, 17.85127 -29.566...
# 22  POLYGON ((20.10970 -32.90966, 19.35458 -33.528...
# 23  POLYGON ((20.72710 -32.39661, 19.98493 -33.017...
# 24  POLYGON ((23.39372 -30.07649, 22.43213 -30.937...
# 25  POLYGON ((18.39375 -29.86137, 17.71165 -30.485...
# 26  POLYGON ((18.97031 -29.33006, 18.30000 -29.954...
# 27  POLYGON ((19.53971 -28.79520, 18.88054 -29.419...
# 28  POLYGON ((20.10385 -28.25724, 19.45382 -28.882...
# 29  POLYGON ((20.21432 -33.55986, 19.44087 -34.175...
# 30  POLYGON ((20.84219 -33.05296, 20.08269 -33.670...
# 31  POLYGON ((21.46117 -32.54174, 20.71626 -33.160...
# 32  POLYGON ((22.07420 -32.02676, 21.34130 -32.646...
# 33  POLYGON ((22.67952 -31.50902, 21.95973 -32.129...
# 34  POLYGON ((23.55045 -30.75128, 22.56960 -31.609...
# 35  POLYGON ((18.91421 -30.30295, 18.22410 -30.926...
# 36  POLYGON ((19.49903 -29.77368, 18.81889 -30.397...
# 37  POLYGON ((20.07466 -29.24085, 19.40599 -29.864...
# 38  POLYGON ((20.64333 -28.70562, 19.98608 -29.329...
#
#                                                browse   shortname
# 0   https://data.lpdaac.earthdatacloud.nasa.gov/lp...  EMITL2ARFL
# 1   https://data.lpdaac.earthdatacloud.nasa.gov/lp...  EMITL2ARFL
# 2   https://data.lpdaac.earthdatacloud.nasa.gov/lp...  EMITL2ARFL
# 3   https://data.lpdaac.earthdatacloud.nasa.gov/lp...  EMITL2ARFL
# 4   https://data.lpdaac.earthdatacloud.nasa.gov/lp...  EMITL2ARFL
# 5   https://data.lpdaac.earthdatacloud.nasa.gov/lp...  EMITL2ARFL
# 6   https://data.lpdaac.earthdatacloud.nasa.gov/lp...  EMITL2ARFL
# 7   https://data.lpdaac.earthdatacloud.nasa.gov/lp...  EMITL2ARFL
# 8   https://data.lpdaac.earthdatacloud.nasa.gov/lp...  EMITL2ARFL
# 9   https://data.lpdaac.earthdatacloud.nasa.gov/lp...  EMITL2ARFL
# 10  https://data.lpdaac.earthdatacloud.nasa.gov/lp...  EMITL2ARFL
# 11  https://data.lpdaac.earthdatacloud.nasa.gov/lp...  EMITL2ARFL
# 12  https://data.lpdaac.earthdatacloud.nasa.gov/lp...  EMITL2ARFL
# 13  https://data.lpdaac.earthdatacloud.nasa.gov/lp...  EMITL2ARFL
# 14  https://data.lpdaac.earthdatacloud.nasa.gov/lp...  EMITL2ARFL
# 15  https://data.lpdaac.earthdatacloud.nasa.gov/lp...  EMITL2ARFL
# 16  https://data.lpdaac.earthdatacloud.nasa.gov/lp...  EMITL2ARFL
# 17  https://data.lpdaac.earthdatacloud.nasa.gov/lp...  EMITL2ARFL
# 18  https://data.lpdaac.earthdatacloud.nasa.gov/lp...  EMITL2ARFL
# 19  https://data.lpdaac.earthdatacloud.nasa.gov/lp...  EMITL2ARFL
# 20  https://data.lpdaac.earthdatacloud.nasa.gov/lp...  EMITL2ARFL
# 21  https://data.lpdaac.earthdatacloud.nasa.gov/lp...  EMITL2ARFL
# 22  https://data.lpdaac.earthdatacloud.nasa.gov/lp...  EMITL2ARFL
# 23  https://data.lpdaac.earthdatacloud.nasa.gov/lp...  EMITL2ARFL
# 24  https://data.lpdaac.earthdatacloud.nasa.gov/lp...  EMITL2ARFL
# 25  https://data.lpdaac.earthdatacloud.nasa.gov/lp...  EMITL2ARFL
# 26  https://data.lpdaac.earthdatacloud.nasa.gov/lp...  EMITL2ARFL
# 27  https://data.lpdaac.earthdatacloud.nasa.gov/lp...  EMITL2ARFL
# 28  https://data.lpdaac.earthdatacloud.nasa.gov/lp...  EMITL2ARFL
# 29  https://data.lpdaac.earthdatacloud.nasa.gov/lp...  EMITL2ARFL
# 30  https://data.lpdaac.earthdatacloud.nasa.gov/lp...  EMITL2ARFL
# 31  https://data.lpdaac.earthdatacloud.nasa.gov/lp...  EMITL2ARFL
# 32  https://data.lpdaac.earthdatacloud.nasa.gov/lp...  EMITL2ARFL
# 33  https://data.lpdaac.earthdatacloud.nasa.gov/lp...  EMITL2ARFL
# 34  https://data.lpdaac.earthdatacloud.nasa.gov/lp...  EMITL2ARFL
# 35  https://data.lpdaac.earthdatacloud.nasa.gov/lp...  EMITL2ARFL
# 36  https://data.lpdaac.earthdatacloud.nasa.gov/lp...  EMITL2ARFL
# 37  https://data.lpdaac.earthdatacloud.nasa.gov/lp...  EMITL2ARFL
# 38  https://data.lpdaac.earthdatacloud.nasa.gov/lp...  EMITL2ARFL
#
# [39 rows x 30 columns]

# %%
# Plot Using Folium

# Create Figure and Select Background Tiles
fig = Figure(width="750px", height="375px")
map1 = folium.Map(tiles='https://mt1.google.com/vt/lyrs=y&x={x}&y={y}&z={z}', attr='Google')
fig.add_child(map1)

# Plot STAC EMITL2ARFL Results - note we must drop the datetime_obj columns for this to work
emit_gdf.drop(columns=['datetime_obj']).explore(
    "granule",
    categorical=True,
    tooltip=[
        "granule",
        "start_datetime",
        "cloud_cover",
    ],
    popup=True,
    style_kwds=dict(fillOpacity=0.1, width=2),
    name="EMIT",
    m=map1,
    legend=False
)



# Plot Region of Interest
polygon.explore(
    popup=False,
    style_kwds=dict(fillOpacity=0.1, width=2),
    name="Region of Interest",
    m=map1
)

folium.GeoJson(roi_poly,
                name='bounding_box',
                ).add_to(map1)

map1.fit_bounds(bounds=convert_bounds(gdf.unary_union.bounds))
map1.add_child(folium.LayerControl())
display(fig)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 9
#       6 fig.add_child(map1)
#       8 # Plot STAC EMITL2ARFL Results - note we must drop the datetime_obj columns for this to work
# ----> 9 emit_gdf.drop(columns=['datetime_obj']).explore(
#      10     "granule",
#      11     categorical=True,
#      12     tooltip=[
#      13         "granule",
#      14         "start_datetime",
#      15         "cloud_cover",
#      16     ],
#      17     popup=True,
#      18     style_kwds=dict(fillOpacity=0.1, width=2),
#      19     name="EMIT",
#      20     m=map1,
#      21     legend=False
#      22 )
#      26 # Plot Region of Interest
#      27 polygon.explore(
#      28     popup=False,
#      29     style_kwds=dict(fillOpacity=0.1, width=2),
#      30     name="Region of Interest",
#      31     m=map1
#      32 )
#
# NameError: name 'emit_gdf' is not defined

# %%
gdf.columns
# Out:
# Index(['size', 'meta.concept-type', 'meta.concept-id', 'meta.revision-id',
#        'meta.native-id', 'meta.provider-id', 'meta.format',
#        'meta.revision-date',
#        'umm.TemporalExtent.RangeDateTime.BeginningDateTime',
#        'umm.TemporalExtent.RangeDateTime.EndingDateTime', 'umm.GranuleUR',
#        'umm.AdditionalAttributes',
#        'umm.SpatialExtent.HorizontalSpatialDomain.Geometry.GPolygons',
#        'umm.ProviderDates', 'umm.CollectionReference.ShortName',
#        'umm.CollectionReference.Version', 'umm.PGEVersionClass.PGEName',
#        'umm.PGEVersionClass.PGEVersion', 'umm.RelatedUrls', 'umm.CloudCover',
#        'umm.DataGranule.DayNightFlag',
#        'umm.DataGranule.ArchiveAndDistributionInformation',
#        'umm.DataGranule.ProductionDateTime', 'umm.Platforms',
#        'umm.MetadataSpecification.URL', 'umm.MetadataSpecification.Name',
#        'umm.MetadataSpecification.Version', 'geometry', 'browse', 'shortname'],
#       dtype='object')

# %%
keep_cols = ['meta.concept-id','meta.native-id', 'umm.TemporalExtent.RangeDateTime.BeginningDateTime','umm.TemporalExtent.RangeDateTime.EndingDateTime','umm.CloudCover','umm.DataGranule.DayNightFlag','geometry','browse', 'shortname']
# Remove unneeded columns
gdf = gdf[gdf.columns.intersection(keep_cols)]
gdf.head()
# Out:
#        meta.concept-id                                meta.native-id  \
# 0  G2621941049-LPCLOUD  EMIT_L2A_RFL_001_20230107T082503_2300705_010
# 1  G2621941455-LPCLOUD  EMIT_L2A_RFL_001_20230107T082515_2300705_011
# 2  G2621941650-LPCLOUD  EMIT_L2A_RFL_001_20230107T082527_2300705_012
# 3  G2621944360-LPCLOUD  EMIT_L2A_RFL_001_20230107T082539_2300705_013
# 4  G2621944396-LPCLOUD  EMIT_L2A_RFL_001_20230107T082550_2300705_014
#
#   umm.TemporalExtent.RangeDateTime.BeginningDateTime  \
# 0                               2023-01-07T08:25:03Z
# 1                               2023-01-07T08:25:15Z
# 2                               2023-01-07T08:25:27Z
# 3                               2023-01-07T08:25:39Z
# 4                               2023-01-07T08:25:50Z
#
#   umm.TemporalExtent.RangeDateTime.EndingDateTime  umm.CloudCover  \
# 0                            2023-01-07T08:25:15Z               0
# 1                            2023-01-07T08:25:27Z               0
# 2                            2023-01-07T08:25:39Z               3
# 3                            2023-01-07T08:25:50Z               3
# 4                            2023-01-07T08:26:02Z               0
#
#   umm.DataGranule.DayNightFlag  \
# 0                          Day
# 1                          Day
# 2                          Day
# 3                          Day
# 4                          Day
#
#                                             geometry  \
# 0  POLYGON ((18.23870 -28.49792, 17.69559 -29.066...
# 1  POLYGON ((18.80566 -29.03512, 18.26646 -29.609...
# 2  POLYGON ((19.37742 -29.56899, 18.84355 -30.149...
# 3  POLYGON ((19.95217 -30.09955, 19.42645 -30.685...
# 4  POLYGON ((20.54642 -30.62619, 20.01682 -31.218...
#
#                                               browse   shortname
# 0  https://data.lpdaac.earthdatacloud.nasa.gov/lp...  EMITL2ARFL
# 1  https://data.lpdaac.earthdatacloud.nasa.gov/lp...  EMITL2ARFL
# 2  https://data.lpdaac.earthdatacloud.nasa.gov/lp...  EMITL2ARFL
# 3  https://data.lpdaac.earthdatacloud.nasa.gov/lp...  EMITL2ARFL
# 4  https://data.lpdaac.earthdatacloud.nasa.gov/lp...  EMITL2ARFL

# %%
gdf.rename(columns = {'meta.concept-id':'concept_id','meta.native-id':'granule',
                       'umm.TemporalExtent.RangeDateTime.BeginningDateTime':'start_datetime',
                      'umm.TemporalExtent.RangeDateTime.EndingDateTime':'end_datetime',
                      'umm.CloudCover':'cloud_cover',
                      'umm.DataGranule.DayNightFlag':'day_night'}, inplace=True)
gdf.head()
# Out:
#             concept_id                                       granule  \
# 0  G2621941049-LPCLOUD  EMIT_L2A_RFL_001_20230107T082503_2300705_010
# 1  G2621941455-LPCLOUD  EMIT_L2A_RFL_001_20230107T082515_2300705_011
# 2  G2621941650-LPCLOUD  EMIT_L2A_RFL_001_20230107T082527_2300705_012
# 3  G2621944360-LPCLOUD  EMIT_L2A_RFL_001_20230107T082539_2300705_013
# 4  G2621944396-LPCLOUD  EMIT_L2A_RFL_001_20230107T082550_2300705_014
#
#          start_datetime          end_datetime  cloud_cover day_night  \
# 0  2023-01-07T08:25:03Z  2023-01-07T08:25:15Z            0       Day
# 1  2023-01-07T08:25:15Z  2023-01-07T08:25:27Z            0       Day
# 2  2023-01-07T08:25:27Z  2023-01-07T08:25:39Z            3       Day
# 3  2023-01-07T08:25:39Z  2023-01-07T08:25:50Z            3       Day
# 4  2023-01-07T08:25:50Z  2023-01-07T08:26:02Z            0       Day
#
#                                             geometry  \
# 0  POLYGON ((18.23870 -28.49792, 17.69559 -29.066...
# 1  POLYGON ((18.80566 -29.03512, 18.26646 -29.609...
# 2  POLYGON ((19.37742 -29.56899, 18.84355 -30.149...
# 3  POLYGON ((19.95217 -30.09955, 19.42645 -30.685...
# 4  POLYGON ((20.54642 -30.62619, 20.01682 -31.218...
#
#                                               browse   shortname
# 0  https://data.lpdaac.earthdatacloud.nasa.gov/lp...  EMITL2ARFL
# 1  https://data.lpdaac.earthdatacloud.nasa.gov/lp...  EMITL2ARFL
# 2  https://data.lpdaac.earthdatacloud.nasa.gov/lp...  EMITL2ARFL
# 3  https://data.lpdaac.earthdatacloud.nasa.gov/lp...  EMITL2ARFL
# 4  https://data.lpdaac.earthdatacloud.nasa.gov/lp...  EMITL2ARFL

# %%
gdf['datetime_obj'] = pd.to_datetime(gdf['start_datetime'])

# %%
gdf.hist(column='datetime_obj', by='shortname', bins=10, color='green', edgecolor='black', linewidth=1, sharey=True)
# Out:
# <Axes: title={'center': 'EMITL2ARFL'}>

# %%
gdf.hist(column='datetime_obj', by='shortname', bins=10, color='green', edgecolor='black', linewidth=1, sharey=True)
# Out:
# <Axes: title={'center': 'EMITL2ARFL'}>

# %%
pd.options.mode.chained_assignment = None  # default='warn'

# Split into two dataframes - ECO and EMIT
eco_gdf = gdf[gdf['granule'].str.contains('ECO')]
emit_gdf = gdf[gdf['granule'].str.contains('EMIT')]
print(f' ECOSTRESS Granules: {eco_gdf.shape[0]} \n EMIT Granules: {emit_gdf.shape[0]}')
# Out:
#  ECOSTRESS Granules: 0
#  EMIT Granules: 39

# %%
emit_gdf.head()
# Out:
#             concept_id                                       granule  \
# 0  G2621941049-LPCLOUD  EMIT_L2A_RFL_001_20230107T082503_2300705_010
# 1  G2621941455-LPCLOUD  EMIT_L2A_RFL_001_20230107T082515_2300705_011
# 2  G2621941650-LPCLOUD  EMIT_L2A_RFL_001_20230107T082527_2300705_012
# 3  G2621944360-LPCLOUD  EMIT_L2A_RFL_001_20230107T082539_2300705_013
# 4  G2621944396-LPCLOUD  EMIT_L2A_RFL_001_20230107T082550_2300705_014
#
#          start_datetime          end_datetime  cloud_cover day_night  \
# 0  2023-01-07T08:25:03Z  2023-01-07T08:25:15Z            0       Day
# 1  2023-01-07T08:25:15Z  2023-01-07T08:25:27Z            0       Day
# 2  2023-01-07T08:25:27Z  2023-01-07T08:25:39Z            3       Day
# 3  2023-01-07T08:25:39Z  2023-01-07T08:25:50Z            3       Day
# 4  2023-01-07T08:25:50Z  2023-01-07T08:26:02Z            0       Day
#
#                                             geometry  \
# 0  POLYGON ((18.23870 -28.49792, 17.69559 -29.066...
# 1  POLYGON ((18.80566 -29.03512, 18.26646 -29.609...
# 2  POLYGON ((19.37742 -29.56899, 18.84355 -30.149...
# 3  POLYGON ((19.95217 -30.09955, 19.42645 -30.685...
# 4  POLYGON ((20.54642 -30.62619, 20.01682 -31.218...
#
#                                               browse   shortname  \
# 0  https://data.lpdaac.earthdatacloud.nasa.gov/lp...  EMITL2ARFL
# 1  https://data.lpdaac.earthdatacloud.nasa.gov/lp...  EMITL2ARFL
# 2  https://data.lpdaac.earthdatacloud.nasa.gov/lp...  EMITL2ARFL
# 3  https://data.lpdaac.earthdatacloud.nasa.gov/lp...  EMITL2ARFL
# 4  https://data.lpdaac.earthdatacloud.nasa.gov/lp...  EMITL2ARFL
#
#                datetime_obj
# 0 2023-01-07 08:25:03+00:00
# 1 2023-01-07 08:25:15+00:00
# 2 2023-01-07 08:25:27+00:00
# 3 2023-01-07 08:25:39+00:00
# 4 2023-01-07 08:25:50+00:00

# %%
eco_gdf['intersects'] = eco_gdf.intersects(emit_gdf.unary_union)
eco_gdf = eco_gdf[eco_gdf['intersects'] == True]
print('EMIT Granules: {emit_gdf.shape[0]}')
# Out:
# EMIT Granules: {emit_gdf.shape[0]}

# %%
def concurrent_match(gdf_a:pd.DataFrame, gdf_b:pd.DataFrame, col_name:str, time_delta:timedelta):
    """
    Cross references dataframes containing a datetime object column and keeps rows in 
    each that fall within the provided timedelta of the other. Acceptable time_delta examples:
    
    months=1
    days=1
    hours=1
    minutes=1
    seconds=1 

    """
    # Match Timestamps from Dataframe A with Time-range of entries in Dataframe B
    # Create empty list
    a_list = []
    # Iterate results for product a based on index values
    for _n in gdf_b.index.to_list():
        # Find where product b is within the window of each product a result
        a_matches = (gdf_a[col_name] > gdf_b[col_name][_n]-time_delta) & (gdf_a[col_name] < gdf_b[col_name][_n]+time_delta)
        # Append list with values
        a_list.append(a_matches)
    # Match Timestamps from Dataframe B with Time-range of entries in Dataframe A
    # Create empty list
    b_list =[]
    for _m in gdf_a.index.to_list():
        # Find where product a is within the window of each product b result
        b_matches = (gdf_b[col_name] > gdf_a[col_name][_m]-time_delta) &  (gdf_b[col_name] < gdf_a[col_name][_m]+time_delta)
        # Append list with values
        b_list.append(b_matches)
    # Filter Original Dataframes by summing list of bools, 0 = outside of all time-ranges
    a_filtered = gdf_a.loc[sum(a_list) > 0]
    b_filtered = gdf_b.loc[sum(b_list) > 0]
    return(a_filtered, b_filtered)

# %%
# Plot Using Folium

# Create Figure and Select Background Tiles
fig = Figure(width="750px", height="375px")
map1 = folium.Map(tiles='https://mt1.google.com/vt/lyrs=y&x={x}&y={y}&z={z}', attr='Google')
fig.add_child(map1)

# Plot STAC EMITL2ARFL Results - note we must drop the datetime_obj columns for this to work
emit_gdf.drop(columns=['datetime_obj']).explore(
    "granule",
    categorical=True,
    tooltip=[
        "granule",
        "start_datetime",
        "cloud_cover",
    ],
    popup=True,
    style_kwds=dict(fillOpacity=0.1, width=2),
    name="EMIT",
    m=map1,
    legend=False
)



# Plot Region of Interest
polygon.explore(
    popup=False,
    style_kwds=dict(fillOpacity=0.1, width=2),
    name="Region of Interest",
    m=map1
)

folium.GeoJson(roi_poly,
                name='bounding_box',
                ).add_to(map1)

map1.fit_bounds(bounds=convert_bounds(gdf.unary_union.bounds))
map1.add_child(folium.LayerControl())
display(fig)
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6ce96df6d314a2ed382ef5849db7cf35 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6ce96df6d314a2ed382ef5849db7cf35&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6ce96df6d314a2ed382ef5849db7cf35 = L.map(
#                 &quot;map_6ce96df6d314a2ed382ef5849db7cf35&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f045debacf19d0bb82dfc10dcfea3c4a = L.tileLayer(
#                 &quot;https://mt1.google.com/vt/lyrs=y\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {&quot;attribution&quot;: &quot;Google&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f045debacf19d0bb82dfc10dcfea3c4a.addTo(map_6ce96df6d314a2ed382ef5849db7cf35);
#
#
#         function geo_json_92c37bc338c54b19c1fc9c49a1433ac0_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;1&quot;:
#                     return {&quot;color&quot;: &quot;#1f77b4&quot;, &quot;fillColor&quot;: &quot;#1f77b4&quot;, &quot;fillOpacity&quot;: 0.1, &quot;weight&quot;: 2, &quot;width&quot;: 2};
#                 case &quot;2&quot;: case &quot;3&quot;:
#                     return {&quot;color&quot;: &quot;#aec7e8&quot;, &quot;fillColor&quot;: &quot;#aec7e8&quot;, &quot;fillOpacity&quot;: 0.1, &quot;weight&quot;: 2, &quot;width&quot;: 2};
#                 case &quot;4&quot;: case &quot;5&quot;:
#                     return {&quot;color&quot;: &quot;#ff7f0e&quot;, &quot;fillColor&quot;: &quot;#ff7f0e&quot;, &quot;fillOpacity&quot;: 0.1, &quot;weight&quot;: 2, &quot;width&quot;: 2};
#                 case &quot;6&quot;: case &quot;7&quot;:
#                     return {&quot;color&quot;: &quot;#ffbb78&quot;, &quot;fillColor&quot;: &quot;#ffbb78&quot;, &quot;fillOpacity&quot;: 0.1, &quot;weight&quot;: 2, &quot;width&quot;: 2};
#                 case &quot;10&quot;: case &quot;11&quot;:
#                     return {&quot;color&quot;: &quot;#98df8a&quot;, &quot;fillColor&quot;: &quot;#98df8a&quot;, &quot;fillOpacity&quot;: 0.1, &quot;weight&quot;: 2, &quot;width&quot;: 2};
#                 case &quot;12&quot;: case &quot;13&quot;:
#                     return {&quot;color&quot;: &quot;#d62728&quot;, &quot;fillColor&quot;: &quot;#d62728&quot;, &quot;fillOpacity&quot;: 0.1, &quot;weight&quot;: 2, &quot;width&quot;: 2};
#                 case &quot;14&quot;: case &quot;15&quot;:
#                     return {&quot;color&quot;: &quot;#ff9896&quot;, &quot;fillColor&quot;: &quot;#ff9896&quot;, &quot;fillOpacity&quot;: 0.1, &quot;weight&quot;: 2, &quot;width&quot;: 2};
#                 case &quot;16&quot;: case &quot;17&quot;:
#                     return {&quot;color&quot;: &quot;#9467bd&quot;, &quot;fillColor&quot;: &quot;#9467bd&quot;, &quot;fillOpacity&quot;: 0.1, &quot;weight&quot;: 2, &quot;width&quot;: 2};
#                 case &quot;18&quot;:
#                     return {&quot;color&quot;: &quot;#c5b0d5&quot;, &quot;fillColor&quot;: &quot;#c5b0d5&quot;, &quot;fillOpacity&quot;: 0.1, &quot;weight&quot;: 2, &quot;width&quot;: 2};
#                 case &quot;19&quot;: case &quot;20&quot;:
#                     return {&quot;color&quot;: &quot;#8c564b&quot;, &quot;fillColor&quot;: &quot;#8c564b&quot;, &quot;fillOpacity&quot;: 0.1, &quot;weight&quot;: 2, &quot;width&quot;: 2};
#                 case &quot;21&quot;: case &quot;22&quot;:
#                     return {&quot;color&quot;: &quot;#c49c94&quot;, &quot;fillColor&quot;: &quot;#c49c94&quot;, &quot;fillOpacity&quot;: 0.1, &quot;weight&quot;: 2, &quot;width&quot;: 2};
#                 case &quot;2

# %%
eco_gdf = eco_gdf[eco_gdf['granule'].str.contains("10SGD")]

# %%
print(f' ECOSTRESS Granules: {eco_gdf.shape[0]} \n EMIT Granules: {emit_gdf.shape[0]}')
# Out:
#  ECOSTRESS Granules: 0
#  EMIT Granules: 39

# %%
cols = 3
rows = math.ceil(len(emit_gdf)/cols)
fig, ax = plt.subplots(rows, cols, figsize=(20,20))
ax = ax.flatten()

for _n, index in enumerate(emit_gdf.index.to_list()):
    img = io.imread(emit_gdf['browse'][index])
    ax[_n].imshow(img)
    ax[_n].set_title(f"Index: {index} - {emit_gdf['granule'][index]}")
    ax[_n].axis('off')
plt.tight_layout()
plt.show()
