# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('FIIRMS_Monthly_Data.csv')

df.plot(x='Month',y=['2023_fires ','2022_fires', '2021_fires','2020_fires','2019_fires','2018_fires'], kind='line',figsize=(10, 10))
# Out:
# <Axes: xlabel='Month'>
